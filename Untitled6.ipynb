# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinapadilla/grupo-5-progrmacion-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data

img=np.zeros((200,200))
for i in range(200):
  for j in range(200):
    if(i<=j):
      img[i][j]=255
      
plt.imshow(img, cmap='gray')

# %%
import numpy as np
from skimage import filters
import matplotlib.pyplot as plt
from skimage import data
img2=data.chelsea()
filtro = filters.sobel
img_fil=filtro(img2)
plt.imshow(img2,)
plt.show()
plt.imshow(img_fil)
